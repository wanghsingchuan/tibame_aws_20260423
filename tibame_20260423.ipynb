# %% [markdown]
# <a href="https://colab.research.google.com/github/wanghsingchuan/tibame_aws_20260423/blob/main/tibame_20260423.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tibame AWS 雲端工程師
#
# 1. jupyter notebok使用的筆記: markdown語法
#
# 2. colab是一個線上版本的jupyter notebook
#
# 3. 一個完整的python程式應該會以.py作為結尾(從第一行到最後一行)
#
# 4. 一個練習的jupyter notebook會以.ipynb作為結尾
#
# 5. 支援特殊語法: Latex Math : $ Area = \frac {1}{2} \pi R^2 $

# %% [markdown]
# # 完全平方日
#
# 當天日期 (20241001) 開根號是整數 (即 $4499^2$)
#
# 題目: 從20241001往後數出10個完全平方日
#
# 確認1. 數值判斷是否為日期
#
# 確認2. 2月天數處理，正常28天，閏年+1天(29天) [每4年1閏, 每100年不閏, 每400年閏]
#
# 想法1. 20241001 20241002...20720704, 大概要數48年(48*365=17520)個日期才能數到
#
# 想法2. 4499 4500 ... 4552, 你數(4552-4499=53)個整數就能數到

# %%
# 確認是否閏年
year = 777

# 正常方式
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 ==0:
            print('閏年')
        else:
            print('平年')
    else:
        print('閏年')
else:
    print('平年')

# 改良: 篩選方式
if year % 400 == 0:
    print('閏年')
elif year % 100 == 0:
    print('平年')
elif year % 4 == 0:
    print('閏年')
else:
    print('平年')
# Out:
# False

# %% [markdown]
# #20260423 想法2.實作
# 含自我練習, 完成題目
#
# 問題:
#
#
# 1.   is_date()沒有處理: 大小月與2月閏年+1天，處理方式詳 20260428

# %%
class Date:
    # 設定Date(年,月,日)
    def set_data(self, year, month, day):
        self.year = year
        self.month = month
        self.day = day

    # 確認1.是否符合日期格式
    # 沒有處理大小月與2月閏年+1天，處理方式詳: 20260428
    def is_date(self):
        if (31 >= self.day > 0) and (12 >= self.month > 0) and (self.year >= 1911):
            return True
        else:
            return False

    # 確認2.是否閏年
    # 規則: 每4年1閏, 每100年不閏, 每400年閏
    def is_leap_year(self):
        if self.year % 400 == 0:
            return True
        elif self.year % 100 == 0:
            return False
        elif self.year % 4 == 0:
            return True
        else:
            return False


i = 4499
count = 0
while count < 100:

    d = i * i           #數值d = 20241001拆成年月日
    day = d % 100       #日:   01, 20241001除100取餘數
    d_tmp = d // 100    #除100取商, 替換d = 202410, 用來取月
    month = d_tmp % 100 #月:   10, 202410除100取餘數
    year = d_tmp // 100 #年: 2024, 202410除100取商

    # 設定: 取年year 月month 日day
    date = Date()
    date.set_data(year, month, day)

    # 排除閏年 and 確認為日期樣式: 年(1911-), 月(1-12), 日(1-31)
    if not date.is_leap_year() and date.is_date():
        print('完全平方日:', d, '[', year, '年', month, '月', day,'日 ]')
        count += 1
    i = i + 1
# Out:
# 完全平方日: 20930625 [ 2093 年 6 月 25 日 ]
# 完全平方日: 21150801 [ 2115 年 8 月 1 日 ]
# 完全平方日: 21390625 [ 2139 年 6 月 25 日 ]
# 完全平方日: 21650409 [ 2165 年 4 月 9 日 ]
# 完全平方日: 21790224 [ 2179 年 2 月 24 日 ]
# 完全平方日: 22071204 [ 2207 年 12 月 4 日 ]
# 完全平方日: 22231225 [ 2223 年 12 月 25 日 ]
# 完全平方日: 22420225 [ 2242 年 2 月 25 日 ]
# 完全平方日: 22591009 [ 2259 年 10 月 9 日 ]
# 完全平方日: 23011209 [ 2301 年 12 月 9 日 ]
# 完全平方日: 23020804 [ 2302 年 8 月 4 日 ]
# 完全平方日: 23030401 [ 2303 年 4 月 1 日 ]
# 完全平方日: 23571025 [ 2357 年 10 月 25 日 ]
# 完全平方日: 23970816 [ 2397 年 8 月 16 日 ]
# 完全平方日: 23980609 [ 2398 年 6 月 9 日 ]
# 完全平方日: 23990404 [ 2399 年 4 月 4 日 ]
# 完全平方日: 24651225 [ 2465 年 12 月 25 日 ]
# 完全平方日: 24730729 [ 2473 年 7 月 29 日 ]
# 完全平方日: 24750625 [ 2475 年 6 月 25 日 ]
# 完全平方日: 24770529 [ 2477 年 5 月 29 日 ]
# 完全平方日: 24820324 [ 2482 年 3 月 24 日 ]
# 完全平方日: 24850225 [ 2485 年 2 月 25 日 ]
# 完全平方日: 24890121 [ 2489 年 1 月 21 日 ]
# 完全平方日: 25110121 [ 2511 年 1 月 21 日 ]
# 完全平方日: 25150225 [ 2515 年 2 月 25 日 ]
# 完全平方日: 25180324 [ 2518 年 3 月 24 日 ]
# ...

# %% [markdown]
# #20260428 想法2.實作
#
# 宣告涵式, 回傳所有**完全平方日的清單**

# %%
# d = 20240230
# day = d % 100
# remain = d // 100
# month = remain % 100
# year = remain // 100
# print(year, month, day)

# if year >= 1:
#     if 12 >= month >= 1:
#         month_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
#         days_max = month_days[month-1]
#         if is_leap_year(year) and month == 2:
#             days_max = days_max + 1
#         if days_max >= day >= 1:
#             print('日期合理')
#         else:
#             print('日期不合理')
#     else:
#         print('月份不合理')
# else:
#     print('年份不合理')

# %%
# 閏年判定
def is_leap_year(year):
    # year = 2000
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False
# print(is_leap_year(year))

# %%
# 日期確認
def is_date_valid(d):
    day = d % 100
    remain = d // 100
    month = remain % 100
    year = remain // 100

    if year >= 1:
        if 12 >= month >= 1:
            month_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
            days_max = month_days[month-1]
            if is_leap_year(year) and month == 2:
                days_max = days_max + 1
            if days_max >= day >= 1:
                return True
            else:
                return False
        else:
            return False
    else:
        return False

# print(is_date_valid(200010229))

# %%
# 主程式
start = 4499
result = []
count = 0

while count < 10:
    date = start ** 2
    year = date // 10000
    if is_date_valid(date):

        # 清單專屬功能(直接使用即生效, 不用設定回去的動作): append
        result.append(date)

        count = count + 1
    start = start + 1

# print(result)

# %%
# 主程式寫成涵式
def get_squared_2(start=4499, max_count=10):
    result = []
    count = 0

    while count < max_count:
        date = start ** 2
        year = date // 10000
        if is_date_valid(date):

            # 清單專屬功能(直接使用即生效, 不用設定回去的動作): append
            result.append(date)

            count = count + 1
        start = start + 1
    return result

s_dates = get_squared_2(max_count=20)
print(s_dates)
print(s_dates[-2])
# Out:
# [20241001, 20720704, 20930625, 21150801, 21390625, 21520321, 21641104, 21650409, 21790224, 21921124, 22071204, 22080601, 22231225, 22420225, 22591009, 22600516, 22800625, 23011209, 23020804, 23030401]
# 23020804

# %% [markdown]
# #20260428 想法1.實作 (作業)
#
# 確認開根號是否為整數 [float內建的is_integer()]

# %%
import datetime as dt

# 字串轉日期型態
d = dt.datetime.strptime("20260428","%Y%m%d")

# 日期型態轉字串
d.strftime("會議時間: %Y/%m/%d(%a)")

# 日期增加減少
d = dt.datetime(2000, 2, 28)
delta = dt.timedelta(days=1)
print(d+delta)
# Out:
# 2000-02-29 00:00:00

# %%
start = dt.datetime(2024, 10, 1)
delta = dt.timedelta(days=1)
result = []
count = 0

while count < 10:
    # 日期 ->字串 ->整數
    # 開根號確認為整數
    # count + 1
    date = int(start.strftime('%Y%m%d'))
    if (date ** 0.5).is_integer():
        result.append(date)
        count = count + 1
    start = start + delta

print(result)
# Out:
# [20241001, 20720704, 20930625, 21150801, 21390625, 21520321, 21641104, 21650409, 21790224, 21921124]

# %%
# 把想法1 變成函式
def get_squared_1(y=2024, m=10, d=1, max_count=10):
    start = dt.datetime(y, m, d)
    delta = dt.timedelta(days=1)
    result = []
    count = 0

    while count < max_count:
        # 日期 ->字串 ->整數
        # 開根號確認為整數
        # count + 1
        date = int(start.strftime('%Y%m%d'))
        if (date ** 0.5).is_integer():
            result.append(date)
            count = count + 1
        start = start + delta

    return result

get_squared_1(max_count=5)
# Out:
# [20241001, 20720704, 20930625, 21150801, 21390625]
